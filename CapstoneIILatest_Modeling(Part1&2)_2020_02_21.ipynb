# %%
#import needed libraries to start


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

from yahoo_fin import stock_info as si
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %matplotlib inline

from IPython.display import display

#remove warnings
import warnings
warnings.filterwarnings('ignore')

import pandas_datareader.data as web
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#!pip install requests_html

# %%
#get the stock data for stock symbol entry using pandas_datareader

stock_symbol = input("Enter a stock symbol (for example, AAPL): ")
data = web.get_data_yahoo(stock_symbol, '1/1/2016', '2/21/2020',)
data.reset_index(inplace=True,drop=False)
# Out:
# Enter a stock symbol (for example, AAPL): AAPL

# %%
data.head(10)
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2016-01-04  105.370003  102.000000  102.610001  105.349998  67649400.0
# 1 2016-01-05  105.849998  102.410004  105.750000  102.709999  55791000.0
# 2 2016-01-06  102.370003   99.870003  100.559998  100.699997  68457400.0
# 3 2016-01-07  100.129997   96.430000   98.680000   96.449997  81094400.0
# 4 2016-01-08   99.110001   96.760002   98.550003   96.959999  70798000.0
# 5 2016-01-11   99.059998   97.339996   98.970001   98.529999  49739400.0
# 6 2016-01-12  100.690002   98.839996  100.550003   99.959999  49154200.0
# 7 2016-01-13  101.190002   97.300003  100.320000   97.389999  62439600.0
# 8 2016-01-14  100.480003   95.739998   97.959999   99.519997  63170100.0
# 9 2016-01-15   97.709999   95.360001   96.199997   97.129997  79833900.0
#
#    Adj Close
# 0  98.213585
# 1  95.752419
# 2  93.878586
# 3  89.916473
# 4  90.391907
# 5  91.855568
# 6  93.188705
# 7  90.792793
# 8  92.778496
# 9  90.550415

# %%
data.tail(10)
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 1031 2020-02-07  323.399994  318.000000  322.369995  320.029999  29421000.0
# 1032 2020-02-10  321.549988  313.850006  314.179993  321.549988  27337200.0
# 1033 2020-02-11  323.899994  318.709991  323.600006  319.609985  23580800.0
# 1034 2020-02-12  327.220001  321.470001  321.470001  327.200012  28432600.0
# 1035 2020-02-13  326.220001  323.350006  324.190002  324.869995  23686900.0
# 1036 2020-02-14  325.980011  322.850006  324.739990  324.950012  20028400.0
# 1037 2020-02-18  319.750000  314.609985  315.359985  319.000000  38132800.0
# 1038 2020-02-19  324.570007  320.000000  320.000000  323.619995  23496000.0
# 1039 2020-02-20  324.649994  318.209991  322.630005  320.299988  25048900.0
# 1040 2020-02-21  320.420013  310.500000  318.619995  313.049988  28992314.0
#
#        Adj Close
# 1031  320.029999
# 1032  321.549988
# 1033  319.609985
# 1034  327.200012
# 1035  324.869995
# 1036  324.950012
# 1037  319.000000
# 1038  323.619995
# 1039  320.299988
# 1040  313.049988

# %%
#extracting the year, month, and the day from the column 'Date'
data['Year'] = pd.DatetimeIndex(data['Date']).year
data['Month'] = pd.DatetimeIndex(data['Date']).month
data['Day'] = pd.DatetimeIndex(data['Date']).day

# %%
data.head()
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2016-01-04  105.370003  102.000000  102.610001  105.349998  67649400.0
# 1 2016-01-05  105.849998  102.410004  105.750000  102.709999  55791000.0
# 2 2016-01-06  102.370003   99.870003  100.559998  100.699997  68457400.0
# 3 2016-01-07  100.129997   96.430000   98.680000   96.449997  81094400.0
# 4 2016-01-08   99.110001   96.760002   98.550003   96.959999  70798000.0
#
#    Adj Close  Year  Month  Day
# 0  98.213585  2016      1    4
# 1  95.752419  2016      1    5
# 2  93.878586  2016      1    6
# 3  89.916473  2016      1    7
# 4  90.391907  2016      1    8

# %%
data.tail()
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 1036 2020-02-14  325.980011  322.850006  324.739990  324.950012  20028400.0
# 1037 2020-02-18  319.750000  314.609985  315.359985  319.000000  38132800.0
# 1038 2020-02-19  324.570007  320.000000  320.000000  323.619995  23496000.0
# 1039 2020-02-20  324.649994  318.209991  322.630005  320.299988  25048900.0
# 1040 2020-02-21  320.420013  310.500000  318.619995  313.049988  28992314.0
#
#        Adj Close  Year  Month  Day
# 1036  324.950012  2020      2   14
# 1037  319.000000  2020      2   18
# 1038  323.619995  2020      2   19
# 1039  320.299988  2020      2   20
# 1040  313.049988  2020      2   21

# %%
#check the skewness of Close
print ("The skewness of Close on training data is:", data['Close'].skew())
plt.hist(data['Close'], color='red')
plt.show()
# Out:
# The skewness of Close on training data is: 0.7283292829311766

# %%
#taking log of Close to reduce the skewness
target = np.log(data['Close'])
print ("The skewness of the log of Close on the data is:", target.skew())
plt.hist(target, color='red')
plt.show()
# Out:
# The skewness of the log of Close on the data is: -0.010951833751650937

# %%
#check for missing values
null_data = pd.DataFrame(data.isnull().sum().sort_values(ascending=False))[:50]

null_data.columns = ['Null Count']
null_data.index.name = 'Feature'
null_data
# Out:
#            Null Count
# Feature
# Day                 0
# Month               0
# Year                0
# Adj Close           0
# Volume              0
# Close               0
# Open                0
# Low                 0
# High                0
# Date                0

# %%
#create a DF for log transformation of Close
data['logClose']=np.log(data['Close']+1)

data.head()
data.shape
# Out:
# (1041, 11)

# %%
data.head()
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2016-01-04  105.370003  102.000000  102.610001  105.349998  67649400.0
# 1 2016-01-05  105.849998  102.410004  105.750000  102.709999  55791000.0
# 2 2016-01-06  102.370003   99.870003  100.559998  100.699997  68457400.0
# 3 2016-01-07  100.129997   96.430000   98.680000   96.449997  81094400.0
# 4 2016-01-08   99.110001   96.760002   98.550003   96.959999  70798000.0
#
#    Adj Close  Year  Month  Day  logClose
# 0  98.213585  2016      1    4  4.666736
# 1  95.752419  2016      1    5  4.641599
# 2  93.878586  2016      1    6  4.622027
# 3  89.916473  2016      1    7  4.579339
# 4  90.391907  2016      1    8  4.584559

# %%
x = data.drop(columns = ['Date', 'logClose', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'])
y = data['logClose']

display(x.head())
display(y.head())
# Out:
#    Year  Month  Day
# 0  2016      1    4
# 1  2016      1    5
# 2  2016      1    6
# 3  2016      1    7
# 4  2016      1    8
# 0    4.666736
# 1    4.641599
# 2    4.622027
# 3    4.579339
# 4    4.584559
# Name: logClose, dtype: float64

# %%
#split the given train dataset into training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.35, shuffle=False)
x_train.head()
# Out:
#    Year  Month  Day
# 0  2016      1    4
# 1  2016      1    5
# 2  2016      1    6
# 3  2016      1    7
# 4  2016      1    8

# %%
#import needed libraries
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import Lasso
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error

#create a function to calculate the mean absolute percentage error
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def printScore(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    rmsle = np.sqrt(mean_squared_log_error(y_true, y_pred))
    
    print('Evaluation Metrics')
    print('MAE         : %0.4f ' % mae)
    print('MAPE        : %0.4f ' % mape)
    print('RMSLE       : %0.4f ' % rmsle)

# %% [markdown]
# !pip install lightgbm

# %%
#Linear Regression

lr = LinearRegression(n_jobs = -1)

lr.fit(x_train, y_train)

y_pred = lr.predict(x_train)

print('-------Linear Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = lr.predict(x_test)

print('')
print('-------Linear Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# -------Linear Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0479
# MAPE        : 0.9775
# RMSLE       : 0.0097
#
# -------Linear Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.2137
# MAPE        : 4.0591
# RMSLE       : 0.0387

# %%
#LR_Lasso
model_lasso = Lasso(random_state=42,alpha=0.00035)
lr_lasso = make_pipeline(RobustScaler(), model_lasso)
lr_lasso.fit(x_train,y_train)



y_pred = lr_lasso.predict(x_train)

print('-------LR_lasso Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = lr_lasso.predict(x_test)

print('')
print('-------LR_lasso Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# -------LR_lasso Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0478
# MAPE        : 0.9765
# RMSLE       : 0.0097
#
# -------LR_lasso Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.2113
# MAPE        : 4.0141
# RMSLE       : 0.0383

# %%
#LGBM Regression
lgb = lgb.LGBMRegressor()
lgb.fit(x_train, y_train)

y_pred = lgb.predict(x_train)

print('-------LGBM Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = lgb.predict(x_test)

print('')
print('-------LGBM Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# -------LGBM Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0108
# MAPE        : 0.2200
# RMSLE       : 0.0025
#
# -------LGBM Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.1493
# MAPE        : 2.7186
# RMSLE       : 0.0354

# %%
#RandomForest Regression
forest_reg = RandomForestRegressor(n_estimators=1, min_samples_leaf=1, max_features=0.5, n_jobs=-1, oob_score=True)
forest_reg.fit(x_train, y_train)

y_pred = forest_reg.predict(x_train)

print('-------RandomForest Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = forest_reg.predict(x_test)

print('')
print('-------RandomForest Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# -------RandomForest Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0197
# MAPE        : 0.3948
# RMSLE       : 0.0111
#
# -------RandomForest Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.1864
# MAPE        : 3.3921
# RMSLE       : 0.0453

# %%
#GBoost Regression
model_GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.0156,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =42)

model_GBoost.fit(x_train, y_train)

y_pred = model_GBoost.predict(x_train)

print('-------GradientBoosting Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = model_GBoost.predict(x_test)

print('')
print('------- GradientBoosting Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# -------GradientBoosting Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0104
# MAPE        : 0.2122
# RMSLE       : 0.0026
#
# ------- GradientBoosting Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.1554
# MAPE        : 2.8317
# RMSLE       : 0.0357

# %%
#XGBoost Regression
XGB_regr = xgb.XGBRegressor(learning_rate=0.01,n_estimators=3460,
                                     max_depth=3, min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27,
                                     reg_alpha=0.00006)

XGB_regr.fit(x_train, y_train)

y_pred = XGB_regr.predict(x_train)

print('-------XGB Regression(on Training Set)--------')
printScore(y_train, y_pred)

y_pred = XGB_regr.predict(x_test)

print('')
print('------- XGB Regression(on Test Set)------')
printScore(y_test, y_pred)
# Out:
# [16:14:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# -------XGB Regression(on Training Set)--------
# Evaluation Metrics
# MAE         : 0.0147
# MAPE        : 0.3003
# RMSLE       : 0.0032
#
# ------- XGB Regression(on Test Set)------
# Evaluation Metrics
# MAE         : 0.1460
# MAPE        : 2.6694
# RMSLE       : 0.0355

# %%
# showing the visualization of the predicted stock prices vs the actual stock prices using different models
def VizPricePredict(model, name):
    PredictPrice = np.exp(model.predict(x))-1
    
    plt.figure(figsize = (18,9))
    plt.plot(data['Adj Close'], color = 'black', label = 'Actual Stock Price')
    plt.plot(PredictPrice, color = 'green', label = 'Predicted Stock Price')
    plt.title('Stock Price Prediction-'+name)
    plt.xlabel('Time Unit')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

# %%
VizPricePredict(lr, 'Linear Regression')

# %%
VizPricePredict(lr_lasso, 'Linear Regression_Lasso')

# %%
VizPricePredict(XGB_regr, 'XGB')

# %%
VizPricePredict(forest_reg, 'RFR')

# %%
VizPricePredict(lgb, 'LGB')

# %%
VizPricePredict(model_GBoost, 'GBoost')

# %%
#making stock price prediction for the future
import datetime
#a function to get user's input for the date for the stock price prediction
def ObtainDate():
    isValid=False
    while not isValid:
        userIn = input("Enter the target date for the stock price prediction (dd/mm/yyyy)(for example: 01/02/2025) ")
        try: # strptime throws an exception if the input doesn't match the pattern
            d = datetime.datetime.strptime(userIn, "%d/%m/%Y")
            isValid=True
        except:
            print ("Doh, try again!\n")
    return d

a = ObtainDate()

targetDate = pd.DataFrame({'Year': [a.year], 'Month': [a.month], 'Day': [a.day]})

def futurePrice(model, td):
    futurePrice = np.exp(model.predict(td))-1
    return futurePrice

#using the best models to predict

print ('Using model of LR, the future stock price is:', futurePrice(lr, targetDate))
print ('Using model of LR_Lasso, the future stock price is:', futurePrice(lr_lasso, targetDate))
print ('Using model of XBG, the future stock price is:', futurePrice(XGB_regr , targetDate))
print ('Using model of RFR, the future stock price is:', futurePrice(forest_reg , targetDate))
print ('Using model of LGBM, the future stock price is:', futurePrice(lgb, targetDate))
print ('Using model of GB, the future stock price is:', futurePrice(model_GBoost, targetDate))
# Out:
# Enter the target date for the stock price prediction (dd/mm/yyyy)(for example: 01/02/2025) 21/02/2020
# Using model of LR, the future stock price is: [329.20949725]
# Using model of LR_Lasso, the future stock price is: [328.02926766]
# Using model of XBG, the future stock price is: [170.35025]
# Using model of RFR, the future stock price is: [171.8500061]
# Using model of LGBM, the future stock price is: [172.35631626]
# Using model of GB, the future stock price is: [171.67510056]

# %% [markdown]
# ## Since stock prices tends to increase over time, it suggests, LR and LR_lasso are the final best models to predict the stock prices.

# %%
#future returns on investment in the chosen stock from today's purchase

def whole_data_training (model, x, y):
        model.fit(x,y)

whole_data_training(lr, x, y)
whole_data_training(lr_lasso, x, y)

#livePrice = si.get_live_price("aapl")
livePrice = float(input("Enter the current price of the stock:) "))

returns = ( (futurePrice(lr, targetDate)+futurePrice(lr_lasso , targetDate))/2 - livePrice)/livePrice
print('The future price on the target date will be prediected as: ', (futurePrice(lr, targetDate)+futurePrice(lr_lasso , targetDate))/2 )
print ('If invested today, the future returns on the chosen stock to the target date is: ', "%.2f" %  (float(returns)*100), '%!')
# Out:
# Enter the current price of the stock:) 320
# The future price on the target date will be prediected as:  [324.08119684]
# If invested today, the future returns on the chosen stock to the target date is:  1.28 %!

# %% [markdown]
# # NLP
#
# In this part, we pre-processed the description of the companies to be prepared for the recommendtion system later on

# %%
import pandas as pd
import numpy as np
import scipy
from scipy.spatial import distance

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# Libraries for text preprocessing
import re # remove punctuations, special characters and digits
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
### Please download these pakages for running this code:
#nltk.download('stopwords')
#nltk.download('wordnet')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('SP500IT.csv')
data.head()
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2016-01-04  105.370003  102.000000  102.610001  105.349998  67649400.0
# 1 2016-01-05  105.849998  102.410004  105.750000  102.709999  55791000.0
# 2 2016-01-06  102.370003   99.870003  100.559998  100.699997  68457400.0
# 3 2016-01-07  100.129997   96.430000   98.680000   96.449997  81094400.0
# 4 2016-01-08   99.110001   96.760002   98.550003   96.959999  70798000.0
#
#    Adj Close  Year  Month  Day  logClose
# 0  98.213585  2016      1    4  4.666736
# 1  95.752419  2016      1    5  4.641599
# 2  93.878586  2016      1    6  4.622027
# 3  89.916473  2016      1    7  4.579339
# 4  90.391907  2016      1    8  4.584559

# %%
#dataset.set_index('ID',inplace= True)
#data.head()

# %% [markdown]
# # Only the information in description will be cleaned and employed

# %%
dataset[['Symbol','Name','Description']].head()
# Out:
#   Symbol                  Name  \
# 0   AAPL             Apple Inc
# 1    ACN         Accenture Plc
# 2   ADBE     Adobe Systems Inc
# 3    ADI        Analog Devices
# 4    ADP  Automatic Data Procs
#
#                                          Description
# 0  Apple Inc. designs, manufactures, and markets ...
# 1  Accenture plc provides consulting, technology,...
# 2  Adobe Inc. operates as a diversified software ...
# 3  Analog Devices, Inc. designs, manufactures, an...
# 4  Automatic Data Processing, Inc. provides cloud...

# %%
dataset_Org = pd.DataFrame(dataset)

# %%
stop_words=set(stopwords.words("english"))

# %% [markdown]
# # Enter the keywords first for the recommendation program to continue

# %%
#cust_input = "I want to have a good apple stock"
#cust_input = "Western Digital Corporation develops, manufactures, and sells data storage devices and solutions worldwide. It offers client devices, including hard disk drives (HDDs) and solid state drives (SSDs) for computing devices, such as desktop and notebook personal computers (PCs), security surveillance systems, gaming consoles, and set top boxes; flash-based embedded storage products for mobile phones, tablets, notebook PCs, and other portable and wearable devices, as well as automotive, Internet of Things, industrial, and connected home applications; flash-based memory wafers; and embedded storage solutions and flash products, such as multi-chip package solutions. The company also provides data center devices and solutions comprising enterprise helium hard drives; enterprise SSDs consisting of flash-based SSDs and software solutions for use in enterprise servers, online transactions, data analysis, and other enterprise applications; data center solutions, including HDDs and drive configurations for use in data storage systems and tiered storage models; system solutions that offer petabyte scalable capacity; and data storage platforms and systems. In addition, it offers client solutions, such as external HDD storage products in mobile and desktop form; client SSDs; removable cards that are used in consumer devices comprising mobile phones, tablets, imaging systems, still and action video cameras, and security surveillance systems; universal serial bus flash drives for use in the computing and consumer markets; and wireless drive products used in-field back up of created content, as well as wireless streaming of high-definition movies, photos, music, and documents to tablets, smartphones, and PCs. The company sells its products under the HGST, SanDisk, and WD brands to original equipment manufacturers, distributors, resellers, cloud infrastructure players, and retailers. Western Digital Corporation was founded"
# This is a short sentence from the Western DIgital's discription and it recommends the right company:
#cust_input = "  and security surveillance systems; universal serial bus flash drives for use in the computing and consumer markets" 
# This is a short sentence from the Fleetcor Technologies Inc's discription and it recommends the right company:
#cust_input = "payments products include virtual cards, purchasing cards, travel and entertainment cards, payroll cards, and cross-border payment facilitation. "
# This is a short sentence from the Seagate's discription and it recommends the right company:
#cust_input = "The company manufactures and distributes hard disk drives; solid state drives"
#Now try a sentence of really from customer search:
cust_input = input("Please enter some keywords:")
# Out:
# Please enter some keywords:radio frequency products

# %%
corpus_input= []
#Remove punctuations
input_text = re.sub('[^a-zA-Z,]', ' ', cust_input)
print(input_text)
#Convert to lowercase
input_text = input_text.lower()
    
#remove tags
input_text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",input_text)

# remove special characters and digits
input_text=re.sub("(\\d|\\W)+"," ",input_text)
    
##Convert to list from string
input_text = input_text.split()
print(input_text)
# Out:
# radio frequency products
# ['radio', 'frequency', 'products']

# %%
lem = WordNetLemmatizer()
input_text = [lem.lemmatize(word) for word in input_text if not word in  stop_words] 
input_text = " ".join(input_text)

corpus_input.append(str(input_text))
print(input_text)
corpus_input

cust_input_tokenized = nltk.word_tokenize(input_text) #tokenize customer input after preprocessed
input_text=cust_input_tokenized
# Out:
# radio frequency product

# %%
BoWA = cust_input_tokenized
BoWA
# Out:
# ['radio', 'frequency', 'product']

# %%
Id = int(100000)
dataset = dataset_Org.append(pd.Series(Id,index=['ID']), ignore_index=True)
dataset.loc[dataset['ID'] == 100000, ['Name','Description']] = ("customer request", corpus_input)
dataset
# Out:
#           ID Symbol                                        Name  \
# 0        1.0   AAPL                                   Apple Inc
# 1        2.0    ACN                               Accenture Plc
# 2        3.0   ADBE                           Adobe Systems Inc
# 3        4.0    ADI                              Analog Devices
# 4        5.0    ADP                        Automatic Data Procs
# 5        6.0    ADS                  Alliance Data Systems Corp
# 6        7.0   ADSK                                Autodesk Inc
# 7        8.0   AKAM                         Akamai Technologies
# 8        9.0   AMAT                           Applied Materials
# 9       10.0    AMD                           Adv Micro Devices
# 10      11.0   ANET                         Arista Networks Inc
# 11      12.0   ANSS                                   Ansys Inc
# 12      13.0    APH                        Amphenol Corporation
# 13      14.0   AVGO                                Broadcom Inc
# 14      15.0     BR          Broadridge Financial Solutions Inc
# 15      16.0   CDNS                  Cadence Design Systems Inc
# 16      17.0    CDW                             CDW Corporation
# 17      18.0    CRM                          salesforce.com Inc
# 18      19.0   CSCO                           Cisco Systems Inc
# 19      20.0   CTSH  Cognizant Technology Solutions Corporation
# 20      21.0   CTXS                          Citrix Systems Inc
# 21      22.0    DXC                      Dxc Technology Company
# 22      23.0   FFIV                             F5 Networks Inc
# 23      24.0    FIS  Fidelity National Information Services Inc
# 24      25.0   FISV                                  Fiserv Inc
# 25      26.0   FLIR                            Flir Systems Inc
# 26      27.0    FLT                   Fleetcor Technologies Inc
# 27      28.0   FTNT                                Fortinet Inc
# 28      29.0    GLW                                 Corning Inc
# 29      30.0    GPN                         Global Payments Inc
# ..       ...    ...                                         ...
# 38      39.0   JNPR                        Juniper Networks Inc
# 39      40.0   KEYS                   Keysight Technologies Inc
# 40      41.0   KLAC                             KLA Corporation
# 41      42.0   LDOS                         Leidos Holdings Inc
# 42      43.0   LRCX                           Lam Research Corp
# 43      44.0     MA                              Mastercard Inc
# 44      45.0   MCHP                        Microchip Technology
# 45      46.0   MSFT                              Microsoft Corp
# 46      47.0    MSI                          Motorola Solutions
# 47      48.0     MU                           Micron Technology
# 48      49.0   MXIM               Maxim Integrated Products Inc
# 49      50.0   NTAP                                  NetApp Inc
# 50      51.0   NVDA                                 Nvidia Corp
# 51      52.0   ORCL                                 Oracle Corp
# 52      53.0   PAYX                                 Paychex Inc
# 53      54.0   PYPL                             Paypal Holdings
# 54      55.0   QCOM                                Qualcomm Inc
# 55      56.0   QRVO                                   Qorvo Inc
# 56      57.0   SNPS                                Synopsys Inc
# 57      58.0    STX                     Seagate Technology plc
# 58      59.0   SWKS                      Skyworks Solutions Inc
# 59      60.0    TEL                         Te Connectivity Ltd
# 60      61.0    TXN                       Texas Instruments Inc
# 61      62.0      V                                    Visa Inc
# 62      63.0   VRSN                                Verisign Inc
# 63      64.0    WDC                 Western Digital Corporation
# 64      65.0     WU                       Western Union Company
# 65      66.0   XLNX                                  Xilinx Inc
# 66      67.0    XRX                  Xerox Holdings Corporation
# 67  100000.0    NaN                            customer request
#
#                   Sector                             Industry  \
# 0             Technology                 Consumer Electronics
# 1             Technology      Information Technology Services
# 2             Technology               Software - Application
# 3             Technology                       Semiconductors
# 4            Industrials                    Business Services
# 5   Financial Services\n                      Credit Services
# 6             Technology               Software - Application
# 7             Technology               Software - Application
# 8             Technology  Semiconductor Equipment & Materials
# 9             Technology                       Semiconductors
# 10            Technology                     Computer Systems
# 11            Technology               Software - Application
# 12            Technology                Electronic Components
# 13            Technology                       Semiconductors
# 14           Industrials                    Business Services
# 15            Technology               Software - Application
# 16            Technology      Information Technology Services
# 17            Technology            Software-Cloud computing
# 18            Technology              Communication Equipment
# 19            Technology      Information Technology Services
# 20            Technology            Software - Infrastructure
# 21            Technology      Information Technology Services
# 22            Technology            Software - Infrastructure
# 23           Industrials                    Business Services
# 24           Industrials                    Business Services
# 25            Technology   Scientific & Technical Instruments
# 26            Technology            Software - Infrastructure
# 27            Technology               Software - Application
# 28            Technology                Electronic Components
# 29           Industrials                    Business Services
# ..                   ...                                  ...
# 38            Technology              Communication Equipment
# 39            Technology   Scientific & Technical Instruments
# 40            Technology  Semiconductor Equipment & Materials
# 41            Technology      Information Technology Services
# 42            Technology  Semiconductor Equipment & Materials
# 43    Financial Services                      Credit Services
# 44            Technology                       Semiconductors
# 45            Technology            Software - Infrastructure
# 46            Technology              Communication Equipment
# 47            Technology                       Semiconductors
# 48            Technology                       Semiconductors
# 49            Technology                         Data Storage
# 50            Technology                       Semiconductors
# 51            Technology            Software - Infrastructure
# 52           Industrials                    Business Services
# 53    Financial Services                      Credit Services
# 54            Technology                       Semiconductors
# 55            Technology                       Semiconductors
# 56            Technology               Software - Application
# 57            Technology                         Data Storage
# 58            Technology                       Semiconductors
# 59            Technology                Electronic Components
# 60            Technology                       Semiconductors
# 61    Financial Services                      Credit Services
# 62            Technology       Internet Content & Information
# 63            Technology                         Data Storage
# 64    Financial Services                      Credit Services
# 65            Technology                       Semiconductors
# 66            Technology      Information Technology Services
# 67                   NaN                                  NaN
#
#    Full Time Employees                          CEO  \
# 0              137,000              Timothy D. Cook
# 1               492000      Julie T. Spellman Sweet
# 2                21357             Shantanu Narayen
# 3               15,800             Vincent T. Roche
# 4               58,000          Carlos A. Rodriguez
# 5                10000             Melisa A. Miller
# 6                9,600              Andrew Anagnost
# 7                7,579          F. Thomson Leighton
# 8               21,600            Gary E. Dickerson
# 9               10,100                   Lisa T. Su
# 10                2300            Jayshree V. Ullal
# 11                3400                Ajei S. Gopal
# 12               73600         Richard Adam Norwitt
# 13               15000                  Hock E. Tan
# 14               11000             Timothy C. Gokey
# 15                7500                   Lip-Bu Tan
# 16                9843           Christine A. Leahy
# 17               35000         Marc Russell Benioff
# 18               75900           Charles H. Robbins
# 19              289900              Brian Humphries
# 20                8200         David James Henshall
# 21              130000           Michael J. Salvino
# 22                5091         Franois Locoh-Donou
# 23               55000           Gary Adam Norcross
# 24               24000  Jeffery W. Yabuki B.S., CPA
# 25                3649              James J. Cannon
# 26                7580             Ronald F. Clarke
# 27                6590                      Ken Xie
# 28               51500             Wendell P. Weeks
# 29               11000        Jeffrey S. Sloan J.D.
# ..                 ...                          ...
# 38               9,283                   Rami Rahim
# 39               13300          Ronald S. Nersesian
# 40               10020           Richard P. Wallace
# 41               33000               Roger A. Krone
# 42               10700            Timothy M. Archer
# 43               14800             Ajaypal S. Banga
# 44               18286               Stephen Sanghi
# 45              144000                Satya Nadella
# 46               16000             Gregory Q. Brown
# 47               34100              Sanjay Mehrotra
# 48                7131                  Tun Doluca
# 49               10500                George Kurian
# 50               13277               Jen-Hsun Huang
# 51              136000          Lawrence J. Ellison
# 52               15600                 Martin Mucci
# 53               21800           Daniel H. Schulman
# 54               35400         Steven M. Mollenkopf
# 55                8100        Robert A. Bruggeworth
# 56               13245              Aart J. de Geus
# 57               40500         William David Mosley
# 58                9400              Liam K. Griffin
# 59               80000       Terrence R. Curtin CPA
# 60               30000         Richard K. Templeton
# 61               17000     Alfred Francis Kelly Jr.
# 62                 900              D. James Bidzos
# 63               61800          Stephen D. Milligan
# 64               12000                 Hikmet Ersek
# 65                4433                  Victor Peng
# 66               27600         Giovanni G. Visentin
# 67                 NaN                          NaN
#
#                                               Address  \
# 0   One Apple Park Way\nCupertino, CA 95014\nUnite...
# 1   1 Grand Canal Square\nGrand Canal Harbour\nDub...
# 2   345 Park Avenue\nSan Jose, CA 95110\nUnited St...
# 3   One Technology Way\nPO Box 9106\nNorwood, MA 0...
# 4   One ADP Boulevard\nRoseland, NJ 07068\nUnited ...
# 5   3075 Loyalty Circle\nColumbus, OH 43219\nUnite...
# 6   111 McInnis Parkway\nSan Rafael, CA 94903\nUni...
# 7   Kendall Square\n145 Broadway\nCambridge, MA 02...
# 8   3050 Bowers Avenue\nPO Box 58039\nSanta Clara,...
# 9   2485 Augustine Drive\nSanta Clara, CA 95054\nU...
# 10  5453 Great America Parkway\nSanta Clara, CA 95...
# 11  2600 ANSYS Drive\nCanonsburg, PA 15317\nUnited...
# 12  358 Hall Avenue\nPO Box 5030\nWallingford, CT ...
# 13  1320 Ridder Park Drive\nSan Jose, CA 95131\nUn...
# 14  5 Dakota Drive\nSuite 300\nLake Success, NY 11...
# 15  2655 Seely Avenue\nBuilding 5\nSan Jose, CA 95...
# 16  75 Tri-State International\nLincolnshire, IL 6...
# 17   Salesforce Tower\nSan Francisco California 94105
# 18  170 West Tasman Drive\nSan Jose, CA 95134\nUni...
# 19  Glenpointe Centre West\n500 Frank West Burr Bo...
# 20  851 West Cypress Creek Road\nFort Lauderdale, ...
# 21  1775 Tysons Boulevard\nTysons, VA 22102\nUnite...
# 22  401 Elliott Avenue West\nSeattle, WA 98119\nUn...
# 23  601 Riverside Avenue\nJacksonville, FL 32204\n...
# 24  255 Fiserv Drive\nBrookfield, WI 53045\nUnited...
# 25  27700 South West Parkway Avenue\nWilsonville, ...
# 26  5445 Triangle Parkway\nSuite 400\nPeachtree Co...
# 27  899 Kifer Road\nSunnyvale, CA 94086\nUnited St...
# 28  One Riverfront Plaza\nCorning, NY 14831\nUnite...
# 29  3550 Lenox Road\nAtlanta, GA 30326\nUnited States
# ..                                                ...
# 38  1133 Innovation Way\nSunnyvale, CA 94089\nUnit...
# 39  1400 Fountaingrove Parkway\nSanta Rosa, CA 954...
# 40  One Technology Drive\nMilpitas, CA 95035\nUnit...
# 41  11951 Freedom Drive\nReston, VA 20190\nUnited ...
# 42  4650 Cushing Parkway\nFremont, CA 94538\nUnite...
# 43  2000 Purchase Street\nPurchase, NY 10577\nUnit...
# 44  2355 West Chandler Boulevard\nChandler, AZ 852...
# 45  One Microsoft Way\nRedmond, WA 98052\nUnited S...
# 46  500 West Monroe Street\nSuite 4400\nChicago, I...
# 47             8000 S FEDERAL WAY\nBOISE ID 83716 USA
# 48  160 Rio Robles\nSan Jose, CA 95134\nUnited States
# 49  1395 Crossman Avenue\nSunnyvale, CA 94089\nUni...
# 50  2788 San Tomas Expressway\nSanta Clara, CA 950...
# 51  500 Oracle Parkway\nRedwood Shores, CA 94065\n...
# 52  911 Panorama Trail South\nRochester, NY 14625\...
# 53  2211 North First Street\nSan Jose, CA 95131\nU...
# 54  5775 Morehouse Drive\nSan Diego, CA 92121\nUni...
# 55  7628 Thorndike Road\nGreensboro, NC 27409\nUni...
# 56  690 East Middlefield Road\nMountain View, CA 9...
# 57        38/39 Fitzwilliam Square\nDublin 2\nIreland
# 58    20 Sylvan Road\nWoburn, MA 01801\nUnited States
# 59    Rheinstrasse 20\nSchaffhausen 8200\nSwitzerland
# 60  12500 TI Boulevard\nDallas, TX 75243\nUnited S...
# 61  PO Box 8999\nSan Francisco, CA 941282-8999\nUn...
# 62  12061 Bluemont Way\nReston, VA 20190\nUnited S...
# 63  5601 Great Oaks Parkway\nSan Jose, CA 95119\nU...
# 64  7001 East Belleview Avenue\nDenver, CO 80237\n...
# 65  2100 Logic Drive\nSan Jose, CA 95124\nUnited S...
# 66  201 Merritt 7\nPO Box 4505\nNorwalk, CT 06851\...
# 67                                                NaN
#
#                                           Description
# 0   Apple Inc. designs, manufactures, and markets ...
# 1   Accenture plc provides consulting, technology,...
# 2   Adobe Inc. operates as a diversified software ...
# 3   Analog Devices, Inc. designs, manufactures, an...
# 4   Automatic Data Processing, Inc. provides cloud...
# 5   Alliance Data Systems Corporation provides dat...
# 6   Autodesk, Inc. operates as a design software a...
# 7   Akamai Technologies, Inc. provides cloud servi...
# 8   Applied Materials, Inc. provides manufacturing...
# 9   Advanced Micro Devices, Inc. operates as a sem...
# 10  Arista Networks, Inc. develops, markets, and s...
# 11  ANSYS, Inc. develops and markets engineering s...
# 12  Amphenol Corporation, together with its subsid...
# 13  Broadcom Inc. designs, develops, and supplies ...
# 14  Broadridge Financial Solutions, Inc. provides ...
# 15  Cadence Design Systems, Inc. provides software...
# 16  CDW Corporation provides integrated informatio...
# 17  salesforce.com, inc. engages in the design and...
# 18  Cisco Systems, Inc. designs, manufactures, and...
# 19  Cognizant Technology Solutions Corporation, a ...
# 20  Citrix Systems, Inc. provides workspace, netwo...
# 21  DXC Technology Company, together with its subs...
# 22  F5 Networks, Inc. develops, markets, and sells...
# 23  Fidelity National Information Services, Inc. o...
# 24  Fiserv, Inc., together with its subsidiaries, ...
# 25  FLIR Systems, Inc. designs, develops, markets,...
# 26  FleetCor Technologies, Inc. provides commercia...
# 27  Fortinet, Inc. provides broad, integrated, and...
# 28  Corning Incorporated engages in display techno...
# 29  Global Payments Inc. provides payment technolo...
# ..                                                ...
# 38  Juniper Networks, Inc. designs, develops, and ...
# 39  Keysight Technologies, Inc. provides electroni...
# 40  KLA Corporation designs, manufactures, and mar...
# 41  Leidos Holdings, Inc. provides services and so...
# 42  Lam Research Corporation designs, manufactures...
# 43  Mastercard Incorporated, a technology company,...
# 44  Microchip Technology Incorporated develops, ma...
# 45  Microsoft Corporation develops, licenses, and ...
# 46  Motorola Solutions, Inc. provides mission-crit...
# 47  Micron Technology, Inc. engages in the provisi...
# 48  Maxim Integrated Products, Inc. designs, devel...
# 49  NetApp, Inc. provides software, systems, and s...
# 50  NVIDIA Corporation operates as a visual comput...
# 51  Oracle Corporation provides products and servi...
# 52  Paychex, Inc. provides integrated human capita...
# 53  PayPal Holdings, Inc. operates as a technology...
# 54  QUALCOMM Incorporated designs, develops, manuf...
# 55  Qorvo, Inc. provides radio frequency (RF) solu...
# 56  Synopsys, Inc. provides electronic design auto...
# 57  Seagate Technology plc provides data storage t...
# 58  Skyworks Solutions, Inc., together with its su...
# 59  TE Connectivity Ltd., together with its subsid...
# 60  Texas Instruments Incorporated designs, manufa...
# 61  Visa Inc. operates as a payments technology co...
# 62  VeriSign, Inc. provides domain name registry s...
# 63  Western Digital Corporation develops, manufact...
# 64  The Western Union Company provides money movem...
# 65  Xilinx, Inc. designs and develops programmable...
# 66  Xerox Holdings Corporation designs, develops, ...
# 67                            radio frequency product
#
# [68 rows x 9 columns]

# %%
corpus= []
for i in range(0, len(dataset['Description'])):
    
    #Remove punctuations
    text = re.sub('[^a-zA-Z,]', ' ', str (dataset['Description'][i]))
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append((text))

# %% [markdown]
# ### All punctuations, special characters, tags are removed and uppercase letters has been standardized to lowercase. Therefore, each stock company's desciption is standardized as a group of lowercased words seperated by a single space so the system can process easily later.

# %%
dataset['Processed'] = corpus

# %%
dataset[['Description','Processed']].head()
# Out:
#                                          Description  \
# 0  Apple Inc. designs, manufactures, and markets ...
# 1  Accenture plc provides consulting, technology,...
# 2  Adobe Inc. operates as a diversified software ...
# 3  Analog Devices, Inc. designs, manufactures, an...
# 4  Automatic Data Processing, Inc. provides cloud...
#
#                                            Processed
# 0  apple inc design manufacture market smartphone...
# 1  accenture plc provides consulting technology o...
# 2  adobe inc operates diversified software compan...
# 3  analog device inc design manufacture market in...
# 4  automatic data processing inc provides cloud b...

# %% [markdown]
# ## The "Proccessed" column will be converted into bag of words (the "BoWB" column) which is a vector of the words as elements  for later algorithm implementation

# %%
BoWB =[]
for i in range(0, len(dataset['Processed'])):
    #Remove punctuations
    text_BoW = re.sub('[^a-zA-Z]', ' ', dataset['Processed'][i])
    text_BoW = text_BoW.split()
    BoWB.append((text_BoW))

# %%
dataset['BoWB'] = BoWB
dataset[['Description','Processed','BoWB']].head()
# Out:
#                                          Description  \
# 0  Apple Inc. designs, manufactures, and markets ...
# 1  Accenture plc provides consulting, technology,...
# 2  Adobe Inc. operates as a diversified software ...
# 3  Analog Devices, Inc. designs, manufactures, an...
# 4  Automatic Data Processing, Inc. provides cloud...
#
#                                            Processed  \
# 0  apple inc design manufacture market smartphone...
# 1  accenture plc provides consulting technology o...
# 2  adobe inc operates diversified software compan...
# 3  analog device inc design manufacture market in...
# 4  automatic data processing inc provides cloud b...
#
#                                                 BoWB
# 0  [apple, inc, design, manufacture, market, smar...
# 1  [accenture, plc, provides, consulting, technol...
# 2  [adobe, inc, operates, diversified, software, ...
# 3  [analog, device, inc, design, manufacture, mar...
# 4  [automatic, data, processing, inc, provides, c...

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=10000, ngram_range=(1,1))
X=cv.fit_transform(dataset['Processed'])

# %% [markdown]
# ## We turned these BoWB into vector for later use of recommendation part

# %%
dataset['dicB'] = X
dataset[['Description','Processed','BoWB','dicB']].head()
# Out:
#                                          Description  \
# 0  Apple Inc. designs, manufactures, and markets ...
# 1  Accenture plc provides consulting, technology,...
# 2  Adobe Inc. operates as a diversified software ...
# 3  Analog Devices, Inc. designs, manufactures, an...
# 4  Automatic Data Processing, Inc. provides cloud...
#
#                                            Processed  \
# 0  apple inc design manufacture market smartphone...
# 1  accenture plc provides consulting technology o...
# 2  adobe inc operates diversified software compan...
# 3  analog device inc design manufacture market in...
# 4  automatic data processing inc provides cloud b...
#
#                                                 BoWB  \
# 0  [apple, inc, design, manufacture, market, smar...
# 1  [accenture, plc, provides, consulting, technol...
# 2  [adobe, inc, operates, diversified, software, ...
# 3  [analog, device, inc, design, manufacture, mar...
# 4  [automatic, data, processing, inc, provides, c...
#
#                                                 dicB
# 0    (0, 247)\t1\n  (0, 449)\t1\n  (0, 1540)\t1\n...
# 1    (0, 247)\t1\n  (0, 449)\t1\n  (0, 1540)\t1\n...
# 2    (0, 247)\t1\n  (0, 449)\t1\n  (0, 1540)\t1\n...
# 3    (0, 247)\t1\n  (0, 449)\t1\n  (0, 1540)\t1\n...
# 4    (0, 247)\t1\n  (0, 449)\t1\n  (0, 1540)\t1\n...

# %% [markdown]
# >>The following are our new progress since last submission. The recommendation of companies upon customer's key word input searching is accomplished. When the customer inputs some words, such as key words of tech terms, or a certain types of products, the outcome is excellent with those searched key words in the discriptions of those correspondingly recommended companies.

# %% [markdown]
# ### import neccessary libraries

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import polynomial_kernel
from sklearn.svm import SVC
from sklearn.metrics.pairwise import sigmoid_kernel 

from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import manhattan_distances

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 1), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(dataset['Processed'])
tfidf_matrix
# Out:
# <68x1965 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6319 stored elements in Compressed Sparse Row format>

# %%
tf.fit(dataset['Processed'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=0, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %% [markdown]
# ## The following is now to compare the input words for searching with all the company discriptions so to find and recommend the companies with their discriptions closest to the searching key words
# ## With trying for a few types of the similarity comparison engines, the finally used one is consine similarity with Sigmoid kernel which ususally gives the best outcome, and it is true for our case here as well.

# %%
cosine_similarities = sigmoid_kernel(tfidf_matrix, tfidf_matrix) 

similarities = cosine_similarities 

results = {}
for idx, row in dataset.iterrows():
    similar_indices = similarities[idx].argsort()[:-100:-1] 
    similar_items = [(similarities[idx][i], dataset['ID'][i]) for i in similar_indices] 
    results[row['ID']] = similar_items[1:]

# %% [markdown]
# # Recommendation 20 outputs based on the keyword entered previously

# %%
def item(id):
    return dataset.loc[dataset['ID'] == id]['Name'].tolist()[0].split(' - ')[0]


def recommend(item_id, num):
    print("Recommending " + str(num) + " products similar to " + item(item_id) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")
        # print(rec)

# recommend(item_id=100000, num=100)
recommend(item_id=100000,num=20)
# Out:
# Recommending 20 products similar to customer request...
# -------
# Recommended: Amphenol Corporation (score:0.7616270133720952)
# Recommended: Qorvo Inc (score:0.7616229776202759)
# Recommended: Maxim Integrated Products Inc (score:0.7616213807056114)
# Recommended: Motorola Solutions (score:0.7616188988209047)
# Recommended: Microchip Technology (score:0.7616182922090029)
# Recommended: Cadence Design Systems Inc (score:0.7616179465728468)
# Recommended: Analog Devices (score:0.7616155927493334)
# Recommended: Cisco Systems Inc (score:0.7616150339695144)
# Recommended: Qualcomm Inc (score:0.7616137050951239)
# Recommended: Keysight Technologies Inc (score:0.7616120383632654)
# Recommended: Texas Instruments Inc (score:0.7616097118148708)
# Recommended: Ansys Inc (score:0.7616064266738871)
# Recommended: Ipg Photonics Corp (score:0.7616056581077012)
# Recommended: Mastercard Inc (score:0.7616051184881159)
# Recommended: CDW Corporation (score:0.7616046994624769)
# Recommended: KLA Corporation (score:0.7616045992634638)
# Recommended: Lam Research Corp (score:0.7616043517629033)
# Recommended: Oracle Corp (score:0.7616029992727489)
# Recommended: Fortinet Inc (score:0.7616028042433118)
# Recommended: Skyworks Solutions Inc (score:0.7616012686941463)
